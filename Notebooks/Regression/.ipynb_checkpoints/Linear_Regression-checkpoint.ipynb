# %%
# Multi Linear Regression

# %% [markdown]
# In this example we will consider sales based on:
#
# - Social Medial Advertiseing expense (in USD 000)
#
# - Print Medial Advertiseing expense (in USD 000)
#
# - Website Maintenance expense (in USD 000)
#
# - Call center average call waiting time
#
#
# Build a linear regression model to predict 'Sales' using using above factors

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# To visualise in the notebook
# %matplotlib inline

# %%
multi_df = pd.read_csv("MultiSales.csv")

# %% [markdown]
# Now, let's check the structure of the advertising dataset.

# %%
# Display the first 5 rows
multi_df.head()
# Out:
#    id  Social  Print  Maint  Waiting   Sales
# 0   1    34.1   13.7     14       28  521.99
# 1   2    30.3   13.9      8       25  423.10
# 2   3    25.0   13.7     10       25  352.04
# 3   4    20.1   15.3     11       29  343.52
# 4   5    28.5   14.0      6       25  411.70

# %%
# Display the last 5 rows
multi_df.tail()
# Out:
#     id  Social  Print  Maint  Waiting   Sales
# 71  72    31.0   17.6     10       28  517.18
# 72  73    31.8   15.5      5       27  532.47
# 73  74    37.3   18.8      7       29  572.01
# 74  75    31.0   22.3      9       26  562.99
# 75  76    29.0   16.7     10       34  415.71

# %%
# Let's check the columns
multi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 6 columns):
# id         76 non-null int64
# Social     76 non-null float64
# Print      76 non-null float64
# Maint      76 non-null int64
# Waiting    76 non-null int64
# Sales      76 non-null float64
# dtypes: float64(3), int64(3)
# memory usage: 3.7 KB

# %%
# Check the shape of the DataFrame (rows, columns)
multi_df.shape
# Out:
# (76, 6)

# %%
# Let's look at some statistical information about the dataframe.
multi_df.describe()
# Out:
#               id     Social      Print      Maint    Waiting       Sales
# count  76.000000  76.000000  76.000000  76.000000  76.000000   76.000000
# mean   38.500000  31.646053  16.194737   9.921053  28.460526  486.837632
# std    22.083176   4.506690   2.797232   2.938313   4.014775   84.078350
# min     1.000000  20.100000  10.000000   5.000000  20.000000  254.190000
# 25%    19.750000  28.750000  14.375000   7.000000  25.750000  429.722500
# 50%    38.500000  31.200000  16.100000  10.000000  28.000000  493.670000
# 75%    57.250000  34.875000  17.625000  12.000000  30.000000  534.410000
# max    76.000000  40.200000  26.000000  15.000000  39.000000  685.550000

# %%
# Visualising Data Using Seaborn

# %%
# Let us do a correlation analysis among the different dimensions and also each dimension with the dependent dimension
# This is done using scatter matrix function which creates a dashboard reflecting useful information about the dimensions
# The result can be stored as a .png file and opened in say, paint to get a larger view 

#axes = pd.plotting.scatter_matrix(mpg_df_attr)
#plt.tight_layout()
#plt.savefig('d:\mpg_pairpanel.png')

sns.pairplot(multi_df)
#sns.pairplot(multi_df, diag_kind='kde')   # to plot density curve instead of histogram

# %%
sns.pairplot(multi_df, diag_kind='kde')   # to plot density curve instead of histogram

# %%
# Perfroming Simple Linear Regression

# %%
# Putting feature variable to X

X = multi_df.drop(["id","Sales"], axis=1)
print(X.shape)
# Print the first 5 rows
X.head()
# Out:
# (76, 4)
#    Social  Print  Maint  Waiting
# 0    34.1   13.7     14       28
# 1    30.3   13.9      8       25
# 2    25.0   13.7     10       25
# 3    20.1   15.3     11       29
# 4    28.5   14.0      6       25

# %%
# Putting response variable to y
y = multi_df[['Sales']]

# Print the first 5 rows
y.head()
# Out:
#     Sales
# 0  521.99
# 1  423.10
# 2  352.04
# 3  343.52
# 4  411.70

# %%
## Splitting Data into Training and Testing Sets

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3 , random_state=5)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (53, 4)
# (53, 1)
# (23, 4)
# (23, 1)

# %%
## Performing Linear Regression

# %%
# import LinearRegression from sklearn
from sklearn.linear_model import LinearRegression

# Representing LinearRegression as lr(Creating LinearRegression Object)
lr_model = LinearRegression()

# Fit the model using lr.fit()
lr_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
## Coefficients Calculation

# %%
# Print the intercept and coefficients
print("Intercept: ", lr_model.intercept_)
for idx, col_name in enumerate(X_train.columns):
    print("The coefficient for {} is {}".format(col_name, lr_model.coef_[0][idx]))
# Out:
# Intercept:  [99.99660494]
# The coefficient for Social is 13.209064026124805
# The coefficient for Print is 7.576604858424309
# The coefficient for Maint is 0.17613606150355646
# The coefficient for Waiting is -5.456611769608147

# %%
## Predictions

# %%
# Making predictions on the testing set
y_pred = lr_model.predict(X_test)

# %%
fig = plt.figure()
plt.scatter(y_pred,y_test-y_pred)
fig.suptitle('Error Terms') 
plt.xlabel('y_pred') 
plt.ylabel('ytest-ypred')
# Out:
# Text(0, 0.5, 'ytest-ypred')

# %%
print("Train")
print(lr_model.score(X_train, y_train))
print("Test")
print(lr_model.score(X_test, y_test))
# Out:
# Train
# 0.8734517064662399
# Test
# 0.835838104024646

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)

# %%
# following is not required since model score already displayed. Shown only for training
r_squared = r2_score(y_test, y_pred)

# %%
print('Mean_Squared_Error :' ,mse)
print('r_square_value :',r_squared)
# Out:
# Mean_Squared_Error : 1143.1531798603542
# r_square_value : 0.8358381040246459

# %%
#extra code to view actual and predicted y in the datafeame

#temp_df = pd.concat([X_test, y_test], axis=1)
#temp_df.head()

# %%
#extra code to view actual and predicted y in the datafeame

#temp_df['Predicted Sales'] = y_pred
#temp_df

# %%
# STATSMODEL

# %%
import statsmodels.api as sm
X_train_sm = X_train
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X_train_sm = sm.add_constant(X_train_sm)
X_train_sm.shape
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# (53, 5)

# %%
# create a fitted model in one line
lm1 = sm.OLS(y_train,X_train_sm).fit()
# print the coefficients
lm1.params
# Out:
# const      99.996605
# Social     13.209064
# Print       7.576605
# Maint       0.176136
# Waiting    -5.456612
# dtype: float64

# %%
print(lm1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.873
# Model:                            OLS   Adj. R-squared:                  0.863
# Method:                 Least Squares   F-statistic:                     82.83
# Date:                Tue, 17 Mar 2020   Prob (F-statistic):           6.25e-21
# Time:                        16:56:45   Log-Likelihood:                -254.81
# No. Observations:                  53   AIC:                             519.6
# Df Residuals:                      48   BIC:                             529.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         99.9966     56.571      1.768      0.083     -13.748     213.741
# Social        13.2091      1.248     10.587      0.000      10.700      15.718
# Print          7.5766      1.815      4.174      0.000       3.927      11.226
# Maint          0.1761      1.567      0.112      0.911      -2.975       3.327
# Waiting       -5.4566      1.192     -4.579      0.000      -7.852      -3.061
# ==============================================================================
# Omnibus:                        4.778   Durbin-Watson:                   2.381
# Prob(Omnibus):                  0.092   Jarque-Bera (JB):                2.190
# Skew:                          -0.166   Prob(JB):                        0.334
# Kurtosis:                       2.061   Cond. No.                         617.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
plt.figure(figsize = (5,5))
sns.heatmap(multi_df.corr(),annot = True)

# %% [markdown]
# # Iteration 2

# %%
X = multi_df.drop(["id","Sales","Maint"], axis=1)
print(X.shape)
# Out:
# (76, 3)

# %%
# Putting response variable to y
y = multi_df[['Sales']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3 , random_state=5)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (53, 3)
# (53, 1)
# (23, 3)
# (23, 1)

# %%
# Fit the model using lr.fit()
lr_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Print the intercept and coefficients
print("Intercept: ", lr_model.intercept_)
for idx, col_name in enumerate(X_train.columns):
    print("The coefficient for {} is {}".format(col_name, lr_model.coef_[0][idx]))
# Out:
# Intercept:  [102.21100944]
# The coefficient for Social is 13.198967961822296
# The coefficient for Print is 7.594896344943708
# The coefficient for Waiting is -5.473697751076099

# %%
# Making predictions on the testing set
y_pred = lr_model.predict(X_test)

# %%
plt.scatter(y_test,y_pred)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
print("Train")
print(lr_model.score(X_train, y_train))
print("Test")
print(lr_model.score(X_test, y_test))
# Out:
# Train
# 0.8734184072466793
# Test
# 0.8373566083043191

# %%
X_train_sm = X_train
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X_train_sm = sm.add_constant(X_train_sm)
X_train_sm.shape
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# (53, 4)

# %%
# create a fitted model in one line
lm1 = sm.OLS(y_train,X_train_sm).fit()

# %%
# print the coefficients
lm1.params
# Out:
# const      102.211009
# Social      13.198968
# Print        7.594896
# Waiting     -5.473698
# dtype: float64

# %%
print(lm1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.873
# Model:                            OLS   Adj. R-squared:                  0.866
# Method:                 Least Squares   F-statistic:                     112.7
# Date:                Tue, 17 Mar 2020   Prob (F-statistic):           5.41e-22
# Time:                        16:56:51   Log-Likelihood:                -254.82
# No. Observations:                  53   AIC:                             517.6
# Df Residuals:                      49   BIC:                             525.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        102.2110     52.492      1.947      0.057      -3.276     207.698
# Social        13.1990      1.232     10.715      0.000      10.724      15.674
# Print          7.5949      1.789      4.244      0.000       3.999      11.191
# Waiting       -5.4737      1.170     -4.679      0.000      -7.825      -3.123
# ==============================================================================
# Omnibus:                        4.773   Durbin-Watson:                   2.370
# Prob(Omnibus):                  0.092   Jarque-Bera (JB):                2.190
# Skew:                          -0.166   Prob(JB):                        0.335
# Kurtosis:                       2.061   Cond. No.                         566.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
